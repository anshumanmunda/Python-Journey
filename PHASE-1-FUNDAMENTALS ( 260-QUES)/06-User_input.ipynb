# %% [markdown]
# # Assignments : User Input and Simple Calculations

# %% [markdown]
# #### 1. Write a python script to take your name as input from the user and then print it.

# %%
# write your code here
name = input("Enter your name: ")
print(name)
# Out:
# anshuman

# %% [markdown]
# #### 2. Write a python script to take input two numbers form the user, then calculate their sum and display the result.

# %%
# write your code here
n1, n2 = int(input("Enter 1st num = ")), int(input("Enter 1st num = "))
print("Sum =",n1 + n2)
# Out:
# Sum = 30

# %% [markdown]
# #### 3. Write a python script which takes the radius from the user and display area of the circle.

# %%
# write your code here
r = float(input("Enter radius of circle: "))
print("Area =",3.14 * r ** 2)
# Out:
# Area = 6358.5

# %% [markdown]
# #### 4. Write a python script to calculate square of a number. Number is entered by the user.

# %%
# write your code here
n = int(input("Enter a number: "))
print("Square =", n**2 )
# Out:
# Square = 1600

# %% [markdown]
# #### 5. Write a python script which takes a character from the user and display its unicode.

# %%
# write your code here
ch = input("Enter a character: ")
print(ch,"=",ord(ch))
# Out:
# Z = 90

# %% [markdown]
# #### 6. Write a python script to calculate simple interest.

# %%
# write your code here
p, r, t = float(input("Enter principal =")), float(input("Enter rate =")), float(input("Enter time ="))
si = (p * r * t) / 100
print("Simple Intrest =",si)
# Out:
# Simple Intrest = 1.2

# %% [markdown]
# #### 7. Write a python script to calculate area of a rectangle.

# %%
# write your code here
l, b = int(input("Enter length =")), int(input("Enter breadth ="))
print("Area of rectangle =", l * b)
# Out:
# Area of rectangle = 20

# %% [markdown]
# #### 8. Write a python script to calculate average of three numbers entered by user.

# %%
# write your code here
n1, n2, n3 = int(input("Enter 1st num = ")),int(input("Enter 2nd num = ")),int(input("Enter 3rd num = "))
print("Average =",( n1 + n2 + n3) / 3 )
# Out:
# Average = 2.0

# %% [markdown]
# #### 9. Write a python script to calculate volume of a cuboid.

# %%
# write your code here
l = int(input("Enter length of cuboid ="))
b = int(input("Enter breadth of cuboid ="))
h = int(input("Enter height of cuboid ="))

print("Volume of cubid =", l * b * h)
# Out:
# Volume of cubid = 0

# %% [markdown]
# #### 10. Write a python script to take two numbers from user (say x and y), now calculate x^y and display the result.

# %%
# write your code here
x, y = int(input(" x = ")), int(input(" x = "))
print(f"{x}^{y} =", x**y)
# Out:
# 2^3 = 8
