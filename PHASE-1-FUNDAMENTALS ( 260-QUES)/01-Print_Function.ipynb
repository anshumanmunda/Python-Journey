# %% [markdown]
# # Assignment : Print Function

# %% [markdown]
# 1. Write a python script to print your name on the screen.

# %%
print("Anshuman Munda")
# Out:
# Anshuman Munda

# %% [markdown]
# 2. Write a python script to print I love on the first line and Python language on the second line.

# %%
print("I love\nPython laguage")
# Out:
# I love
# Python laguage

# %% [markdown]
# 3. Write a python script to print "YourName" on the screen. (Remember to print double quotes)

# %%
print(" \"Anshuman\" ")
# method-2
print('"Anshuman"')
# Out:
#  "Anshuman"
# "Anshuman"

# %% [markdown]
# 4. Write a Python script to print "Teacher's Day" on the screen. (Remember to print double quotes and single quote)

# %%
print("\"Teacher's Day\"")
# #Method-2
print(''' "Teacher's Day" ''')

# %% [markdown]
# 5. Write a python script to print in on the screen.

# %%
print("\\n")
# Out:
# \n
