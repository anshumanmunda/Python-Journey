# %% [markdown]
# ## User Input
#
# This notebook contains hands-on practice for user input.
# Each practical sub-concept is followed by one completely empty code cell.

# %% [markdown]
# #### Taking String Input

# %%
name = input('Enter your name: ')

# %% [markdown]
# #### Taking Integer Input

# %%
age = int(input('Enter your age: '))

# %% [markdown]
# #### Taking Floating-Point Input

# %%
weight = float(input('Enter yor weight: '))

# %% [markdown]
# #### Taking Multiple Inputs with split()
#
# `a, b = input().split()`

# %%
a, b = input('Enter two values seperated by space').split()
print(a)
print(b, type(b))
# Out:
# 10
# 20 <class 'str'>
