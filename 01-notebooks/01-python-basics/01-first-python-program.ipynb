# %% [markdown]
# ## First Python Program

# %% [markdown]
# #### Printing a Simple Message

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# #### Creating Variables in the First Program

# %%
name = 'Anshuman'
age = 22

# %% [markdown]
# #### Taking Basic User Input

# %%
name = input('Enter your name: ')

# %% [markdown]
# #### Running a Multi-Line Python Program
#
# Store values, process them, and display the result in sequence.

# %%
name = 'Anshuman'
age = 22
city = 'Ranchi'

print(name)
print(age)
print(city)
# Out:
# Anshuman
# 22
# Ranchi
