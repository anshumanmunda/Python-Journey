# %% [markdown]
# ## Zip And Parallel Iteration

# %% [markdown]
# #### Combining Two Lists with zip()
#
# Use suitable values to complete combining two lists with zip() and display the result.

# %%
l1 = [100,230,400,50,600]
l2 = ['Paneer', 'Pizza', 'cake', 'Sweet', 'Beear']

new_zip = zip(l1, l2)
list(new_zip)
# Out:
# [(100, 'Paneer'), (230, 'Pizza'), (400, 'cake'), (50, 'Sweet'), (600, 'Beear')]

# %% [markdown]
# #### Parallel Iteration with zip()
#
# Use suitable values to complete parallel iteration with zip() and display the result.

# %% [markdown]
# #### Unzipping Values
#
# Use suitable values to complete unzipping values and display the result.

# %%
l = list()
l = new_zip
l

# %% [markdown]
# #### Creating a Dictionary with zip()
#
# Create dictionary with zip() with suitable sample values and display the result.
