# %% [markdown]
# ## Result Checking Decorator

# %% [markdown]
# #### Checking a Function Result
#
# Check a function result and display the result.

# %% [markdown]
# #### Decorating a Result-Producing Function

# %% [markdown]
# #### Returning the Checked Result
