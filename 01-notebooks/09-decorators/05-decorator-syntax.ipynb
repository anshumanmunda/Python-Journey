# %% [markdown]
# ## Decorator Syntax

# %% [markdown]
# #### Manual Decorator Application
#
# Apply a decorator by assigning the wrapped function back to the original name.

# %% [markdown]
# #### Using @decorator Syntax
#
# Apply the same decorator using the `@` syntax.

# %% [markdown]
# #### Decorating Multiple Functions
