# %% [markdown]
# ## Decorator Coding Problems

# %% [markdown]
# #### Logging Decorator

# %% [markdown]
# #### Timing Decorator
#
# Measure how long a function takes to execute.

# %% [markdown]
# #### Access-Control Decorator

# %% [markdown]
# #### Repeat Decorator
