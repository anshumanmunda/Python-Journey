# %% [markdown]
# ## Nested Functions And Closures

# %% [markdown]
# #### Defining a Nested Function
#
# Define one function inside another and call the inner function.

# %% [markdown]
# #### Returning an Inner Function

# %% [markdown]
# #### Closure over an Outer Variable
#
# Return an inner function that remembers a value from the outer function.

# %% [markdown]
# #### Calling a Closure Multiple Times
