# %% [markdown]
# ## Functions As First Class Objects

# %% [markdown]
# #### Assigning a Function to a Variable
#
# Store a function reference in another variable and call it.

# %% [markdown]
# #### Passing a Function as an Argument
#
# Pass a function into another function and use it on a value.

# %% [markdown]
# #### Returning a Function
#
# An outer function can return an inner function object.

# %% [markdown]
# #### Storing Functions in a Collection
