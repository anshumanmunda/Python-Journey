# %% [markdown]
# ## Simple Decorator

# %% [markdown]
# #### Decorator Function Structure
#
# Create a decorator that adds behaviour before and after another function.

# %% [markdown]
# #### Wrapper Function
#
# The wrapper controls what happens before and after the original function.

# %% [markdown]
# #### Calling the Original Function

# %% [markdown]
# #### Returning the Wrapper
