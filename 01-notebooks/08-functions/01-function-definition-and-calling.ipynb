# %% [markdown]
# ## Function Definition And Calling

# %% [markdown]
# #### Defining a Function
#
# Create a function that displays a greeting message.

# %%
def greet():
  print('Good Morning')
# Out:
# Good Morning

# %% [markdown]
# #### Calling a Function
#
# Call the previously defined function and check its output.

# %%
greet()
# Out:
# Good Morning

# %% [markdown]
# #### Function with Parameters

# %%
def greet(name):
  print(f'Welcome {name}')

greet('Anshuman')
# Out:
# Welcome Anshuman
