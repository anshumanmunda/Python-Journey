# %% [markdown]
# ## Logical Bitwise And Assignment Operators

# %% [markdown]
# #### Logical and

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
10 and 20
# Out:
# 20

# %%
'Ram' and 'Shyam'
# Out:
# 'Shyam'

# %% [markdown]
# #### Logical or

# %%
False or True
# Out:
# True

# %%
20 or 0
# Out:
# 20

# %%
'Ram' or 'Shyam'
# Out:
# 'Ram'

# %% [markdown]
# #### Logical not

# %%
not  True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# #### Bitwise AND

# %%
7 & 12
# Out:
# 4

# %% [markdown]
# #### Bitwise OR

# %%
45 | 26
# Out:
# 63

# %% [markdown]
# #### Bitwise XOR

# %%
45 ^ 26
# Out:
# 55

# %% [markdown]
# #### Bitwise NOT

# %%
~ 45
# Out:
# -46

# %% [markdown]
# #### Left Shift

# %%
4 << 2
# Out:
# 16

# %% [markdown]
# #### Right Shift

# %%
5 >> 1
# Out:
# 2

# %% [markdown]
# #### Assignment Operators

# %%
name = 'Anshuman'

a = 10
b = 20

a += b 
a -= b 
a *= b 
a /= b 
a //= b 
a //= b 
a %= b 
a **= b

# %% [markdown]
# #### Membership Operators

# %%
name = 'Anshuman'
print('a' in name)
print('x' not in name)
# Out:
# True
# True
