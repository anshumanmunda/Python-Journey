# %% [markdown]
# ## String Comparison

# %% [markdown]
# #### Case-Sensitive Comparison
#
# Compare two case-sensitive values and display the result.

# %%
'Hello' > 'hello'
# Out:
# False

# %% [markdown]
# #### Case-Insensitive Comparison
#
# Compare two case-insensitive values and display the result.

# %%
'ApPle' <= 'apple'
# Out:
# True

# %% [markdown]
# #### Lexicographical Comparison
#
# Compare two lexicographical values and display the result.

# %%
'My name is Anshuman'  >= 'zebra'
# Out:
# False
