# %% [markdown]
# ## Set Comprehension

# %% [markdown]
# #### Basic Set Comprehension
#
# A comprehension creates a new collection using a compact iteration expression.

# %% [markdown]
# #### Set Comprehension with Condition
