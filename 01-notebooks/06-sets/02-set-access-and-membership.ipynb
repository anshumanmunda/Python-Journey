# %% [markdown]
# ## Set Access And Membership

# %% [markdown]
# #### Membership Testing in Sets

# %%
st = {10, 20, 60, 30, 10, 3, 0}

10 in st
# Out:
# True

# %% [markdown]
# #### Iterating over a Set
#
# Display each value in a set one by one.

# %%
st = {10, 20, 60, 30, 10, 3, 0}

for e in st:
  print(e, end =' ')
# Out:
# 0 3 20 10 60 30
