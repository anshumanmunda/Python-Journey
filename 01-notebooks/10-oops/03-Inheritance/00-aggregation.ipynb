# %% [markdown]
# ## Aggregration

# %%
class Customer:
  def __init__(self, name, gender, address):
    self.name = name
    self.gender = gender
    self.address = address

  def display(self):
    print(f'Name: {self.name}')
    print(f'Age: {self.gender}')
    print(f'City: {self.address.city}')  
    print(f'Pin code: {self.address.pincode}')  
    print(f'State: {self.address.state}')  

class Address:
  def __init__(self, city, pincode, state):
    self.city = city
    self.pincode = pincode
    self.state = state

add1 = Address('Ranchi', 834001, 'Jharkhand')

c1 = Customer("Anshuman", 'Male', add1)
c1.display()
# Out:
# Name: Anshuman
# Age: Male
# City: Ranchi
# Pin code: 834001
# State: Jharkhand

# %%
class Customer:
  def __init__(self, name, gender, address):
    self.name = name
    self.gender = gender
    self.address = address

  def display(self):
    print(f'Name: {self.name}')
    print(f'Age: {self.gender}')
    print(f'City: {self.address.city}')  
    print(f'Pin code: {self.address.pincode}')  
    print(f'State: {self.address.state}')  

class Address:
  def __init__(self, city, pincode, state):
    self.__city = city
    self.pincode = pincode
    self.state = state

add1 = Address('Ranchi', 834001, 'Jharkhand')

c1 = Customer("Anshuman", 'Male', add1)
c1.display()
# Out:
# Name: Anshuman
# Age: Male
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 23
#      20 add1 = Address('Ranchi', 834001, 'Jharkhand')
#      22 c1 = Customer("Anshuman", 'Male', add1)
# ---> 23 c1.display()
#
# Cell In[8], line 10, in Customer.display(self)
#       8 print(f'Name: {self.name}')
#       9 print(f'Age: {self.gender}')
# ---> 10 print(f'City: {self.address.city}')
#      11 print(f'Pin code: {self.address.pincode}')
#      12 print(f'State: {self.address.state}')
#
# AttributeError: 'Address' object has no attribute 'city'
