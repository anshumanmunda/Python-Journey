# %% [markdown]
# ## Python Errors and Common Exceptions Practice

# %% [markdown]
# #### Fix Missing Parentheses
#
# Correct a `print` statement that is missing parentheses.
#
# Run the corrected version and display the message.

# %%
print "Hello World"
# Out:
#   Cell In[2], line 1
#     print "Hello World"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# #### Fix a Missing Colon
#
# Correct an `if` statement that is missing a colon.
#
# Make the corrected block print a confirmation message.

# %%
age = 20
if age >= 18
  print('You can vote')
# Out:
#   Cell In[4], line 2
#     if age >= 18
#                 ^
# SyntaxError: expected ':'

# %%
age = 20
if age >= 18:
  print('You can vote')
# Out:
# You can vote

# %% [markdown]
# #### Fix Incorrect Keyword Spelling
#
# Correct a wrongly spelled Python keyword in a conditional statement.

# %%
If age >= 18:
  print('You can vote')
# Out:
#   Cell In[6], line 1
#     If age >= 18:
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Fix Incorrect Indentation
#
# Correct an indented block so the code runs properly.

# %%
if age >= 18:
    print('You are adult') 
  print('You can vote')
# Out:
#   File <string>:3
#     print('You can vote')
#                           ^
# IndentationError: unindent does not match any outer indentation level

# %%
if age >= 18:
  print('You are adult') 
  print('You can vote')
# Out:
# You are adult
# You can vote

# %% [markdown]
# #### Use pass in an Empty Block
#
# Create an `if` block that intentionally contains no implementation and use `pass` correctly.

# %%
if age > 5:
# Out:
#   Cell In[10], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
if age > 5 :
  pass

# %% [markdown]
# #### Trigger an IndexError
#
# Create a list with three items and try to access an index that does not exist.
#
# Observe the exception.

# %%
l = [1,2,3]
l[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 l = [1,2,3]
# ----> 2 l[5]
#
# IndexError: list index out of range

# %% [markdown]
# #### Trigger a ModuleNotFoundError
#
# Try importing a module name that does not exist.
#
# Observe the exception.

# %%
import mathi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import mathi
#
# ModuleNotFoundError: No module named 'mathi'

# %% [markdown]
# #### Trigger a KeyError
#
# Create a dictionary with one key and try accessing a missing key.

# %%
d = {
  'name': 'Anshuman',
  'city': 'Ranchi',
}

d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 6
#       1 d = {
#       2   'name': 'Anshuman',
#       3   'city': 'Ranchi',
#       4 }
# ----> 6 d['age']
#
# KeyError: 'age'

# %% [markdown]
# #### Trigger a ValueError
#
# Try converting a non-numeric string into an integer.

# %%
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# #### Trigger a TypeError
#
# Try adding a string and an integer directly.

# %%
'Hello World'  + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 'Hello World'  + 10
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# #### Trigger a NameError
#
# Try displaying a variable that has not been defined.

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# #### Trigger an AttributeError
#
# Create a list and call a string-only method on it.

# %%
l = [1,3,4,5,7]
l.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 l = [1,3,4,5,7]
# ----> 2 l.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# #### Trigger a ZeroDivisionError
#
# Divide a number by zero and observe the runtime exception.

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #### Compare Syntax Error and Runtime Exception
#
# Create one intentionally invalid syntax example and one syntactically correct runtime-error example.
#
# Run them separately and compare when each failure appears.

# %%
# Syntax error
print 'Hello World'
# Out:
#   Cell In[20], line 2
#     print 'Hello World'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
with open('demo.txt', 'r') as f:
  f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 with open('demo.txt', 'r') as f:
#       2   f.read()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demo.txt'
