# %% [markdown]
# ## Python Raise and Business Rules Practice

# %% [markdown]
# #### Raise a Basic Exception

# %%
balance = 500
balance - 1000
if balance < 0:
  raise Exception('Invalid')

# %% [markdown]
# #### Raise a NameError Manually
#
# Raise a `NameError` with your own message.

# %%
d = {
  10: 1,
  20: 2,
  30: 1,
  40: 5,
  10: 3
}

d.get(90, 0)
# Out:
# 0

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# #### Validate a Negative Number
#
# Write a function that raises an exception when the provided number is negative.

# %% [markdown]
# #### Validate Age
#
# Raise an exception when age is below a chosen minimum or above a realistic maximum.

# %% [markdown]
# #### Validate Marks
#
# Raise an exception when marks are outside the range 0 to 100.

# %% [markdown]
# #### Validate a Password Length
#
# Raise an exception when a password is shorter than the required length.

# %% [markdown]
# #### Validate a File Extension
#
# Raise an exception when a filename does not end with an allowed extension.

# %% [markdown]
# #### Validate Withdrawal Amount
#
# Create a bank account class and raise an exception if the withdrawal amount is negative.

# %% [markdown]
# #### Validate Available Balance
#
# Extend the bank class to raise an exception when withdrawal exceeds the balance.

# %% [markdown]
# #### Catch a Raised Exception
#
# Call a function that raises an exception and handle it using `try-except`.

# %% [markdown]
# #### Use else After a Valid Withdrawal
#
# Display the updated balance in `else` only when withdrawal succeeds.

# %% [markdown]
# #### Test Three Withdrawal Cases
#
# Test a valid amount, a negative amount, and an amount larger than the balance.

# %% [markdown]
# #### Create Deposit Validation
#
# Add a deposit method that rejects zero or negative deposits.

# %% [markdown]
# #### Create Transfer Validation
#
# Create a transfer method that validates amount and available balance.

# %% [markdown]
# #### Build a Wallet Class
#
# Create a wallet class that raises errors for invalid add-money and payment operations.

# %% [markdown]
# #### Create an Invalid Coupon Rule
#
# Raise an exception when a coupon is expired or does not meet a minimum-order condition.

# %% [markdown]
# #### Create an Unauthorized Access Rule
#
# Raise an exception when a user role is not permitted to access a protected action.

# %% [markdown]
# #### Build a Registration Validator
#
# Validate username, password, and age using manually raised exceptions.

# %% [markdown]
# #### Build a Business Rule Workflow
#
# Create a small application function with at least three validation rules and catch the raised exceptions cleanly.
