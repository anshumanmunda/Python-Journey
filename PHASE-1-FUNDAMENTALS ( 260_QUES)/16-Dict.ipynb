# %% [markdown]
# # Assignment : Dictionary

# %% [markdown]
# #### 1. Create a Laptop dictionary (brand, model, year).

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
print(d)
# Out:
# {'brand': 'Lenovo', 'model': 'A1B456', 'year': 2023}

# %% [markdown]
# #### 2. Access 'model' using square brackets [].

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}

d['model']
# Out:
# 'A1B456'

# %% [markdown]
# #### 3. Access 'year' using the .get() method.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
d.get('year')
# Out:
# 2023

# %% [markdown]
# #### 4. Add a 'price' key to the dictionary.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}

# %% [markdown]
# #### 5. Update the 'year' value.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
d['year'] = 2024
print(d['year'])
# Out:
# 2024

# %% [markdown]
# #### 6. Delete the 'brand' key using del.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
del d['brand']
print(d)
# Out:
# {'model': 'A1B456', 'year': 2023}

# %% [markdown]
# #### 7. Remove 'model' using .pop().

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
d.pop('model')
print(d)
# Out:
# {'brand': 'Lenovo', 'year': 2023}

# %% [markdown]
# #### 8. Print only the keys of the dictionary.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
for k in d :
  print(k, end=' ')
# Out:
# brand model year

# %% [markdown]
# #### 9. Print only the values of the dictionary.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
# Out:
# brand model year

# %% [markdown]
# #### 10. Print all items using the .items() method.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
print(d.items())
# Out:
# dict_items([('brand', 'Lenovo'), ('model', 'A1B456'), ('year', 2023)])

# %% [markdown]
# #### 11. Check if 'processor' key exists in the dictionary.

# %%
# write your code here 
d = {
  'brand': 'Lenovo',
  'model': 'A1B456',
  'year': 2023
}
if 'processor' in d :
  print("Key `processor` exist.")
else :
  print("Key `processor` don't exist.")
# Out:
# Key `processor` don't exist.

# %% [markdown]
# #### 12. Create a dictionary from two lists (keys and values).

# %%
# write your code here 
key = [1,2,3,4]
value = [10,20,30,40]
i = 0
d =  dict(key = value )
print(d)
# Out:
# {'key': [10, 20, 30, 40]}

# %% [markdown]
# #### 13. Merge two dictionaries using the .update() method.

# %%
# write your code here 
d1 = {'name': 'Anshu',  'roll_num': 57 }
d2 = { 'age': 22,  'city': 'Ranchi'  }

print(d1.update(d2))
# Out:
# None

# %% [markdown]
# #### 14. Count character frequency in a string using a dictionary.

# %%
# write your code here 
s = 'anshuman'

# %% [markdown]
# #### 15. Create a dictionary of cubes for numbers 1-5 using a loop.

# %%
# write your code here 
d = {e: e**2 for e in range(1,6) } 
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# #### 16. Clear all items from the dictionary.

# %%
# write your code here 
d = {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
print(d)
print(d.clear())
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# None

# %% [markdown]
# #### 17. Copy a dictionary into a new variable using .copy().

# %%
# write your code here 
d = {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
temp = d.copy()
print(temp)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# #### 18. Create a nested dictionary representing a Classroom of 3 students.

# %%
# write your code here 
d = {
  'class1':{'name': 'Ajay', 'age': 21},
  'class2':{'name': 'Vijay', 'age': 24},
  'class3':{'name': 'Sanjay', 'age': 19}
}

print(d)
# Out:
# {'class1': {'name': 'Ajay', 'age': 21}, 'class2': {'name': 'Vijay', 'age': 24}, 'class3': {'name': 'Sanjay', 'age': 19}}

# %% [markdown]
# #### 19. Find the key with the highest value in a dictionary.

# %%
# write your code here 
d = {1: 10, 2: 20, 3: 30, 4:0 }
print(max(d))
# Out:
# 4

# %% [markdown]
# #### 20. Reverse a dictionary (swap all keys and values).

# %%
# write your code here 
original_dict = {'1': 10, '2': 20, '3': 30, '4':0 }
print(original_dict)

reversed_dict = {v: k for k,v in d.items()}
print(reversed_dict)
# Out:
# {'1': 10, '2': 20, '3': 30, '4': 0}
# {10: '1', 20: '2', 30: '3', 0: '4'}
